# %%
import eyes17.eyes
import matplotlib.pyplot as plt
import numpy as np

p = eyes17.eyes.open()

# %%
def read_input(time = 2, dt = 4000):
    x, y = p.capture1('A1',int(time*1000000/dt),int(dt))
    return np.array(x), np.array(y)

def f(v):
    if v > 1: return 1
    if v < -1: return -1
    return 0

# %%
t, val = read_input(2, 100)
b = np.array(list(map(f, val)))

# %%
len(val)
# Out:
# 10000

# %%
# plt.plot(t, b)
plt.plot(t[4000:4500], val[4000:4500])
